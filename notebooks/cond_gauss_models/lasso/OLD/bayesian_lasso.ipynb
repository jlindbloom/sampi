# %% [markdown]
# The goal of this notebook is to implement the Bayesian LASSO method for a 1D problem.

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.stats import recipinvgauss
import scipy.sparse as sps
from fastprogress import progress_bar

from IPython.display import clear_output, DisplayHandle
def update_patch(self, obj):
    clear_output(wait=True)
    self.display(obj)
DisplayHandle.update = update_patch

from runningstatistics import StatsTracker
import jlinops

# %% [markdown]
# # Make toy problem

# %%
ground_truth = jlinops.piecewise_constant_1d_test_problem()
n = len(ground_truth)
np.random.seed(0)
noise_stdev = 0.05
noise_var = noise_stdev**2
noisy_signal = ground_truth + noise_stdev*np.random.normal(size=n)
grid = np.arange(n)

# %%
plt.plot(grid, ground_truth, label="Ground truth", color="C0")
plt.scatter(grid, noisy_signal, marker="x", label="Data", color="C1", alpha=1.0, s=0.5)
plt.legend()
plt.show()

# %%
# Define forward operator and regularization matrix
F = jlinops.MatrixLinearOperator(sps.eye(n))
R, _ = jlinops.first_order_derivative_1d(n, boundary="none")
R = jlinops.MatrixLinearOperator(R)

# Set regularization lambda
reg_lambda = 1e2

# %% [markdown]
# # MAP estimate of the L1 problem
#
# By L1 problem, I mean solving
# $$
# \operatorname{argmin}_x \left\{ \frac{1}{2 \sigma^2} \| x - y \|_2^2 + \lambda \| R x \|_1 \right\} = \operatorname{argmin}_x \left\{ \frac{1}{2} \| x - y \|_2^2 + (\lambda \sigma^2) \| R x \|_1 \right\}.
# $$

# %%
# Solution is given by evaluating the proximal operator of the TV norm. This code uses a FDGP method
fdgp_map_result = jlinops.prox_tv1d_norm(noisy_signal, lam=noise_var*reg_lambda, iterations=100)

# %%
plt.scatter(grid, noisy_signal, marker="x", label="Data", color="C1", alpha=1.0, s=0.5)
plt.plot(grid, fdgp_map_result, label="MAP estimate of L1 problem", color="C2")
plt.legend()
plt.show()

# %% [markdown]
# # Sample the posterior of the Gaussian model

# %% [markdown]
# $$
# -\log \pi(x)  = \left\{ \frac{1}{2 \sigma^2} \| x - y \|_2^2 + \frac{\lambda}{2} \| R x \|_2^2 \right\} + C
# $$

# %%
def gauss_posterior_summary(F, R, y, noise_var=1.0, reg_lambda=1e1):
    """Computes posterior mean and stdev.
    """
    Q = sps.csc_matrix((1/noise_var)*(F.A.T @ F.A) + reg_lambda*(R.A.T @ R.A))
    Q = jlinops.MatrixLinearOperator(Q)
    Linv = jlinops.BandedCholeskyFactorInvOperator(Q)
    mean = Linv.T @ (Linv @  ((1/noise_var)*F.T @ y) )

    # Get diagonal entries of Qinv
    Qinv = Linv.T @ Linv
    var = jlinops.black_box_diagonal(Qinv)
    stdev = np.sqrt(var)
    return mean, stdev

# %%
gauss_mu, gauss_sigmas = gauss_posterior_summary(F, R, noisy_signal, noise_var=noise_var, reg_lambda=1e4)
# Out:
#     <div>
#       <progress value='55' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       5.50% [55/1000 00:04&lt;01:13]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/jonathanlindbloom/Github/sampi/notebooks/cond_gauss_models/lasso/bayesian_lasso.ipynb Cell 13 line 1
# ----> <a href='vscode-notebook-cell:/Users/jonathanlindbloom/Github/sampi/notebooks/cond_gauss_models/lasso/bayesian_lasso.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> gauss_mu, gauss_sigmas = gauss_posterior_summary(F, R, noisy_signal, noise_var=noise_var, reg_lambda=1e4)
#
# /Users/jonathanlindbloom/Github/sampi/notebooks/cond_gauss_models/lasso/bayesian_lasso.ipynb Cell 13 line 1
#       <a href='vscode-notebook-cell:/Users/jonathanlindbloom/Github/sampi/notebooks/cond_gauss_models/lasso/bayesian_lasso.ipynb#X15sZmlsZQ%3D%3D?line=8'>9</a> # Get diagonal entries of Qinv
#      <a href='vscode-notebook-cell:/Users/jonathanlindbloom/Github/sampi/notebooks/cond_gauss_models/lasso/bayesian_lasso.ipynb#X15sZmlsZQ%3D%3D?line=9'>10</a> Qinv = Linv.T @ Linv
# ---> <a href='vscode-notebook-cell:/Users/jonathanlindbloom/Github/sampi/notebooks/cond_gauss_models/lasso/bayesian_lasso.ipynb#X15sZmlsZQ%3D%3D?line=10'>11</a> var = jlinops.black_box_diagonal(Qinv)
#      <a href='vscode-notebook-cell:/Users/jonathanlindbloom/Github/sampi/notebooks/cond_gauss_models/lasso/bayesian_lasso.ipynb#X15sZmlsZQ%3D%3D?line=11'>12</a> stdev = np.sqrt(var)
#      <a href='vscode-notebook-cell:/Users/jonathanlindbloom/Github/sampi/notebooks/cond_gauss_models/lasso/bayesian_lasso.ipynb#X15sZmlsZQ%3D%3D?line=12'>13</a> return mean, stdev
#
# File ~/Github/jlinops/src/jlinops/util.py:312, in black_box_diagonal(A)
#     310     tmp = np.zeros(n)
#     311     tmp[j] = 1.0
# --> 312     diag[j] = np.dot(tmp, A @ tmp )
#     314 return diag
#
# File ~/Github/jlinops/src/jlinops/base.py:457, in LinearOperator.__matmul__(self, other)
#     454 if np.isscalar(other):
#     455     raise ValueError("Scalar operands are not allowed, "
#     456                      "use '*' instead")
# --> 457 return self.__mul__(other)
#
# File ~/Github/jlinops/src/jlinops/base.py:410, in LinearOperator.__mul__(self, x)
#     409 def __mul__(self, x):
# --> 410     return self.dot(x)
#
# File ~/Github/jlinops/src/jlinops/base.py:446, in LinearOperator.dot(self, x)
#     443         x = cp.asarray(x)
#     445 if x.ndim == 1 or x.ndim == 2 and x.shape[1] == 1:
# --> 446     return self.matvec(x)
#     447 elif x.ndim == 2:
#     448     return self.matmat(x)
#
# File ~/Github/jlinops/src/jlinops/base.py:217, in LinearOperator.matvec(self, x)
#     214 if x.shape != (N,) and x.shape != (N,1):
#     215     raise ValueError('dimension mismatch')
# --> 217 y = self._matvec(x)
#     219 if isinstance(x, np.matrix):
#     220     y = asmatrix(y)
#
# File ~/Github/jlinops/src/jlinops/base.py:751, in _ProductLinearOperator._matvec(self, x)
#     750 def _matvec(self, x):
# --> 751     return self.args[0].matvec(self.args[1].matvec(x))
#
# File ~/Github/jlinops/src/jlinops/base.py:217, in LinearOperator.matvec(self, x)
#     214 if x.shape != (N,) and x.shape != (N,1):
#     215     raise ValueError('dimension mismatch')
# --> 217 y = self._matvec(x)
#     219 if isinstance(x, np.matrix):
#     220     y = asmatrix(y)
#
# File ~/Github/jlinops/src/jlinops/base.py:672, in _TransposedLinearOperator._matvec(self, x)
#     670 def _matvec(self, x):
#     671     # NB. np.conj works also on sparse matrices
# --> 672     return np.conj(self.A._rmatvec(np.conj(x)))
#
# File ~/Github/jlinops/src/jlinops/base.py:613, in _CustomLinearOperator._rmatvec(self, x)
#     611 if func is None:
#     612     raise NotImplementedError("rmatvec is not defined")
# --> 613 return self.__rmatvec_impl(x)
#
# File ~/Github/jlinops/src/jlinops/cholesky.py:66, in BandedCholeskyFactorInvOperator.__init__.<locals>._rmatvec(x)
#      65 def _rmatvec(x):
# ---> 66     tmp = sp_spsolve_triangular(self.Lmat_t, x, lower=False)
#      67     return tmp
#
# File ~/opt/miniconda3/envs/jlinops/lib/python3.11/site-packages/scipy/sparse/linalg/_dsolve/linsolve.py:732, in spsolve_triangular(A, b, lower, overwrite_A, overwrite_b, unit_diagonal)
#     730 A_column_indices_in_row_i = A.indices[A_off_diagonal_indices_row_i]
#     731 A_values_in_row_i = A.data[A_off_diagonal_indices_row_i]
# --> 732 x[i] -= np.dot(x[A_column_indices_in_row_i].T, A_values_in_row_i)
#     734 # Compute i-th entry of x.
#     735 if not unit_diagonal:
#
# File ~/opt/miniconda3/envs/jlinops/lib/python3.11/site-packages/numpy/core/multiarray.py:741, in dot(a, b, out)
#     671     """
#     672     result_type(*arrays_and_dtypes)
#     673
#    (...)
#     736
#     737     """
#     738     return arrays_and_dtypes
# --> 741 @array_function_from_c_func_and_dispatcher(_multiarray_umath.dot)
#     742 def dot(a, b, out=None):
#     743     """
#     744     dot(a, b, out=None)
#     745
#    (...)
#     829
#     830     """
#     831     return (a, b, out)
#
# KeyboardInterrupt:

# %%
#plt.scatter(grid, noisy_signal, marker="x", label="Data", color="C1", alpha=1.0, s=0.5)
plt.plot(grid, gauss_mu, label="Mean vector", color="C2")
plt.fill_between(grid, gauss_mu - 3*gauss_sigmas, gauss_mu + 3*gauss_sigmas, color="C4", alpha=0.5, label="3 sigma band")
plt.legend()
plt.show()

# %% [markdown]
# # Bayesian LASSO

# %%
class BayesianLASSOGibbsSampler:
    """Implements the Bayesian LASSO hierarchical sampler for the L1 problem.
    """

    def __init__(self, F, R, y, noise_var=1.0, reg_lambda=1.0):

        self.F = F
        self.R = R
        self.y = y
        self.noise_var = noise_var
        self.reg_lambda = reg_lambda


    def sample(self, n_samples, x0=None, n_burn=0, theta_tol=1e-2):
        """Runs the Gibbs sampler.
        """

        # Initialize
        if x0 is None:
            x = np.zeros(self.F.shape[1])
        else:
            x = x0

        # Create trackers
        x_tracker = StatsTracker(self.F.shape[1])
        theta_tracker = StatsTracker(self.R.shape[0])

        # Run the sampler
        for j in progress_bar(range(n_samples+n_burn)):

            # Update theta
            theta = self.sample_theta(x, tol=theta_tol)

            # Update x
            x = self.sample_x(theta)

            # Push to tracker
            if j >= n_burn:
                x_tracker.push(x)
                theta_tracker.push(theta)


        results = {
            "x_tracker": x_tracker,
            "theta_tracker": theta_tracker,
        }

        return results


    def sample_x(self, theta):
        """Given local variances theta, draws a sample for x.
        """

        Q = (1.0/self.noise_var)*(self.F.A.T @ self.F.A) + (1/2)*(self.R.A.T @ ( sps.diags(1.0/theta) @ self.R.A ) )

        # # Bad way
        # Qinv = np.linalg.inv(Q.toarray())
        # mean = Qinv @ ((1.0/self.noise_var)*self.F.T @ self.y )
        # sample = np.random.multivariate_normal(mean, Qinv)

        # Good way
        Q = sps.csc_matrix(Q)
        Q = jlinops.MatrixLinearOperator(Q)
        Linv = jlinops.BandedCholeskyFactorInvOperator(Q)
        mean = Linv.T @ (Linv @ ((1.0/self.noise_var)*self.F.T @ self.y ) )
        sample = mean + ( Linv.T @ np.random.normal(size=Q.shape[0]) )

        return sample
    

    def sample_theta(self, x, tol=1e-2):
        """Given x, draws a sample for the thetas.
        """

        # Get Rx
        Rx = self.R @ x

        # Make output array
        sample = np.zeros(self.R.shape[0])


        # Need to check where Rx is close to zero, so we can sample from exponential there instead
        idx_too_small = np.where(np.abs(Rx) < tol)
        idx_fine = np.where(np.abs(Rx) >= tol)

        # Break into two parts
        Rx_too_small = Rx[idx_too_small]
        Rx_fine = Rx[idx_fine]

        # For the components near zero, sample from the exponential
        theta_from_too_small = np.random.gamma(0.5, scale=2*(1.0/self.reg_lambda), size=len(Rx_too_small))
        #theta_from_too_small = np.random.exponential(scale=1.0/self.reg_lambda, size=len(Rx_too_small))

        # For the components not near zero, sample from the inverse Gaussian
        theta_from_fine = recipinvgauss.rvs(mu=np.sqrt(self.reg_lambda)/np.abs(Rx_fine), scale=1.0/(self.reg_lambda))

        # Put all into one array
        sample[idx_too_small] = theta_from_too_small
        sample[idx_fine] = theta_from_fine

        assert np.all(sample > 0), "some thetas are no positive!"

        return sample

# %%
lasso_sampler = BayesianLASSOGibbsSampler(F, R, noisy_signal, noise_var=noise_var, reg_lambda=0.1*reg_lambda)

# %%
sampling_result = lasso_sampler.sample(n_samples=200, n_burn=1000)
# Out:
#     <div>
#       <progress value='1200' class='' max='1200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1200/1200 01:06&lt;00:00]
#     </div>

# %%
plt.plot(sampling_result["x_tracker"].mean())
plt.title("Mean of unknown (x)")
plt.show()

# %%
plt.plot(sampling_result["theta_tracker"].mean())
plt.title("Mean of local variance parameters (theta)")
plt.show()

# %%
plt.plot(sampling_result["x_tracker"].stdev())
plt.title("Standard deviation of unknown (x)")
plt.show()

# %%
#plt.scatter(grid, noisy_signal, marker="x", label="Data", color="C1", alpha=1.0, s=0.5)
mu, stdev = sampling_result["x_tracker"].mean(), sampling_result["x_tracker"].stdev()
plt.plot(grid, mu, label="Mean vector", color="C2")
plt.fill_between(grid, mu - 3*stdev, mu + 3*stdev, color="C4", alpha=0.5, label="3 sigma band")
plt.legend()
plt.show()

# %%
plt.plot(sampling_result["theta_tracker"].stdev())
plt.title("Standard deviation of local variance parameters (theta)")
plt.show()

# %% [markdown]
# # Comparison with other methods
